# %% [markdown]
# <a href="https://colab.research.google.com/github/khushbu437/Stock-prediction-using-LSTM/blob/main/Stock_Market_Prediction_using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %% [markdown]
# **Loading Data**

# %%
df = pd.read_csv('Google_Stocks.csv')
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
print("Shape of data:", df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()  # Summary of Data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum() # checking null values
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
import matplotlib.pyplot as plt

# Creating a figure with two subplots side by side
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plotting the open prices
ax[0].plot(df['open'], label='Open', color='green')
ax[0].set_xlabel('Date', size=15)
ax[0].set_ylabel('Price', size=15)
ax[0].legend()

# Plotting the closing prices
ax[1].plot(df['close'], label='Close', color='red')
ax[1].set_xlabel('Date', size=15)
ax[1].set_ylabel('Price', size=15)
ax[1].legend()

# Displaying the plots
plt.show()

# %% [markdown]
# **DATA PRE-PROCESSING**

# %%
from sklearn.preprocessing import MinMaxScaler

# Creating a MinMaxScaler object
MMS = MinMaxScaler()

# Applying Min-Max Scaling to normalize all values in the DataFrame
df[df.columns] = MMS.fit_transform(df)

# Displaying the first 10 rows of the normalized DataFrame
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
# Slicing the DataFrame 'df' to create 'train_data' containing the first 'training_size' rows
train_data = df[:training_size]

# Slicing the DataFrame 'df' to create 'test_data' containing the remaining rows after 'training_size'
test_data = df[training_size:]

# Printing the shapes of the newly created 'train_data' and 'test_data'
print(train_data.shape, test_data.shape)
# Out:
# (944, 2) (314, 2)

# %%
# Function to create sequence of data for training and testing
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# **CREATING LSTM MODEL**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(train_seq.shape[1], train_seq.shape[2])))

# Adding a Dropout layer to avoid overfitting (10% of the neurons will be randomly excluded during training)
model.add(Dropout(0.1))

# Adding another LSTM layer with 50 units (return_sequences=False by default for the last LSTM layer)
model.add(LSTM(units=50))

# Adding a Dense layer with 2 neurons (output layer)
model.add(Dense(2))

# Compiling the model with mean squared error loss and Adam optimizer
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# Displaying the summary of the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 95ms/step - loss: 0.0072 - mean_absolute_error: 0.0606 - val_loss: 0.0113 - val_mean_absolute_error: 0.0834
# Epoch 2/100
# 28/28 [==============================] - 2s 60ms/step - loss: 8.0883e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0094 - val_mean_absolute_error: 0.0815
# Epoch 3/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.9099e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0026 - val_mean_absolute_error: 0.0384
# Epoch 4/100
# 28/28 [==============================] - 2s 59ms/step - loss: 4.4407e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0043 - val_mean_absolute_error: 0.0507
# Epoch 5/100
# 28/28 [==============================] - 2s 55ms/step - loss: 4.0572e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0032 - val_mean_absolute_error: 0.0429
# Epoch 6/100
# 28/28 [==============================] - 2s 61ms/step - loss: 4.5257e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0045 - val_mean_absolute_error: 0.0526
# Epoch 7/100
# 28/28 [==============================] - 3s 96ms/step - loss: 4.2072e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0041 - val_mean_absolute_error: 0.0499
# Epoch 8/100
# 28/28 [==============================] - 2s 59ms/step - loss: 4.1076e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0040 - val_mean_absolute_error: 0.0490
# Epoch 9/100
# 28/28 [==============================] - 2s 59ms/step - loss: 3.7895e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0043 - val_mean_absolute_error: 0.0515
# Epoch 10/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.9029e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0029 - val_mean_absolute_error: 0.0408
# Epoch 11/100
# 28/28 [==============================] - 2s 54ms/step - loss: 4.0385e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0035 - val_mean_absolute_error: 0.0454
# Epoch 12/100
# 28/28 [==============================] - 1s 53ms/step - loss: 3.7118e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0036 - val_mean_absolute_error: 0.0462
# Epoch 13/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.4819e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0038 - val_mean_absolute_error: 0.0470
# Epoch 14/100
# 28/28 [==============================] - 2s 86ms/step - loss: 3.6705e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0076 - val_mean_absolute_error: 0.0714
# Epoch 15/100
# 28/28 [==============================] - 2s 69ms/step - loss: 3.3456e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0057 - val_mean_absolute_error: 0.0591
# Epoch 16/100
# 28/28 [==============================] - 2s 59ms/step - loss: 3.3957e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0053 - val_mean_absolute_error: 0.0576
# Epoch 17/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.1969e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0047 - val_mean_absolute_error: 0.0530
# Epoch 18/100
# 28/28 [==============================] - 2s 54ms/step - loss: 3.5601e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0066 - val_mean_absolute_error: 0.0653
# Epoch 19/100
# 28/28 [==============================] - 1s 54ms/step - loss: 3.0161e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0047 - val_mean_absolute_error: 0.0535
# Epoch 20/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.8650e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0080 - val_mean_absolute_error: 0.0734
# Epoch 21/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.8856e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0055 - val_mean_absolute_error: 0.0581
# Epoch 22/100
# 28/28 [==============================] - 3s 91ms/step - loss: 2.8228e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0057 - val_mean_absolute_error: 0.0591
# Epoch 23/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.9269e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0063 - val_mean_absolute_error: 0.0637
# Epoch 24/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.9989e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0051 - val_mean_absolute_error: 0.0573
# Epoch 25/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.7882e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0064 - val_mean_absolute_error: 0.0646
# Epoch 26/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.8335e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0028 - val_mean_absolute_error: 0.0390
# Epoch 27/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.5900e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0072 - val_mean_absolute_error: 0.0694
# Epoch 28/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.9448e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0061 - val_mean_absolute_error: 0.0634
# Epoch 29/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.7748e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0037 - val_mean_absolute_error: 0.0476
# Epoch 30/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.4893e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0036 - val_mean_absolute_error: 0.0443
# Epoch 31/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.6502e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0044 - val_mean_absolute_error: 0.0531
# Epoch 32/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.6714e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0061 - val_mean_absolute_error: 0.0623
# Epoch 33/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.4018e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0058 - val_mean_absolute_error: 0.0606
# Epoch 34/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.4846e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0071 - val_mean_absolute_error: 0.0688
# Epoch 35/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.4482e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0021 - val_mean_absolute_error: 0.0339
# Epoch 36/100
# 28/28 [==============================] - 2s 70ms/step - loss: 2.3561e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0047 - val_mean_absolute_error: 0.0547
# Epoch 37/100
# 28/28 [==============================] - 2s 84ms/step - loss: 2.3834e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0049 - val_mean_absolute_error: 0.0560
# Epoch 38/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.1972e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0055 - val_mean_absolute_error: 0.0601
# Epoch 39/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.2422e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0049 - val_mean_absolute_error: 0.0570
# Epoch 40/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.2077e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 41/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.9806e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0039 - val_mean_absolute_error: 0.0481
# Epoch 42/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.1826e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0054 - val_mean_absolute_error: 0.0603
# Epoch 43/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.0627e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 44/100
# 28/28 [==============================] - 3s 94ms/step - loss: 1.9217e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0057 - val_mean_absolute_error: 0.0612
# Epoch 45/100
# 28/28 [==============================] - 2s 77ms/step - loss: 2.0030e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0036 - val_mean_absolute_error: 0.0454
# Epoch 46/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.0550e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0056 - val_mean_absolute_error: 0.0599
# Epoch 47/100
# 28/28 [==============================] - 2s 60ms/step - loss: 2.0420e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0024 - val_mean_absolute_error: 0.0349
# Epoch 48/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.9902e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0065 - val_mean_absolute_error: 0.0652
# Epoch 49/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.8516e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0050 - val_mean_absolute_error: 0.0569
# Epoch 50/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.9642e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0032 - val_mean_absolute_error: 0.0427
# Epoch 51/100
# 28/28 [==============================] - 3s 92ms/step - loss: 1.8170e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0036 - val_mean_absolute_error: 0.0467
# Epoch 52/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.7217e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0029 - val_mean_absolute_error: 0.0418
# Epoch 53/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7604e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0043 - val_mean_absolute_error: 0.0539
# Epoch 54/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.7748e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0069 - val_mean_absolute_error: 0.0706
# Epoch 55/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.8689e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0060 - val_mean_absolute_error: 0.0674
# Epoch 56/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.7667e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0016 - val_mean_absolute_error: 0.0298
# Epoch 57/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.6429e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 58/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.5711e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0043 - val_mean_absolute_error: 0.0539
# Epoch 59/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.6558e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 60/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.6190e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0028 - val_mean_absolute_error: 0.0421
# Epoch 61/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.7222e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 62/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.5188e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0035 - val_mean_absolute_error: 0.0485
# Epoch 63/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.4407e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0048 - val_mean_absolute_error: 0.0577
# Epoch 64/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.5025e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0024 - val_mean_absolute_error: 0.0393
# Epoch 65/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3830e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0032 - val_mean_absolute_error: 0.0452
# Epoch 66/100
# 28/28 [==============================] - 3s 97ms/step - loss: 1.4558e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0029 - val_mean_absolute_error: 0.0442
# Epoch 67/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7410e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 68/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.4962e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 69/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.4412e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 70/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.5297e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0022 - val_mean_absolute_error: 0.0372
# Epoch 71/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.3867e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0027 - val_mean_absolute_error: 0.0425
# Epoch 72/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3912e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 73/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.4003e-04 - mean_absolute_error: 0.0086 - val_loss: 7.8528e-04 - val_mean_absolute_error: 0.0216
# Epoch 74/100
# 28/28 [==============================] - 2s 82ms/step - loss: 1.4335e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0022 - val_mean_absolute_error: 0.0366
# Epoch 75/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.3230e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0034 - val_mean_absolute_error: 0.0481
# Epoch 76/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2702e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 77/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2066e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 78/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1930e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 79/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.3493e-04 - mean_absolute_error: 0.0084 - val_loss: 9.3588e-04 - val_mean_absolute_error: 0.0235
# Epoch 80/100
# 28/28 [==============================] - 3s 104ms/step - loss: 1.2709e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0025 - val_mean_absolute_error: 0.0399
# Epoch 81/100
# 28/28 [==============================] - 3s 116ms/step - loss: 1.3142e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0014 - val_mean_absolute_error: 0.0290
# Epoch 82/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.1434e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 83/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.1947e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0022 - val_mean_absolute_error: 0.0374
# Epoch 84/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.2290e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0032 - val_mean_absolute_error: 0.0473
# Epoch 85/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0086 - val_loss: 5.5864e-04 - val_mean_absolute_error: 0.0181
# Epoch 86/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1838e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 87/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.2663e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0018 - val_mean_absolute_error: 0.0347
# Epoch 88/100
# 28/28 [==============================] - 3s 96ms/step - loss: 1.1840e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0020 - val_mean_absolute_error: 0.0360
# Epoch 89/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.1932e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0021 - val_mean_absolute_error: 0.0371
# Epoch 90/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.2400e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0026 - val_mean_absolute_error: 0.0412
# Epoch 91/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.2034e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 92/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.1744e-04 - mean_absolute_error: 0.0079 - val_loss: 8.3700e-04 - val_mean_absolute_error: 0.0222
# Epoch 93/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.1950e-04 - mean_absolute_error: 0.0079 - val_loss: 4.8910e-04 - val_mean_absolute_error: 0.0173
# Epoch 94/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.1677e-04 - mean_absolute_error: 0.0076 - val_loss: 9.4423e-04 - val_mean_absolute_error: 0.0230
# Epoch 95/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.1096e-04 - mean_absolute_error: 0.0077 - val_loss: 9.2374e-04 - val_mean_absolute_error: 0.0229
# Epoch 96/100
# 28/28 [==============================] - 2s 85ms/step - loss: 1.0653e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 97/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.0875e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 98/100
# 28/28 [==============================] - 2s 56ms/step - loss: 9.9331e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 99/100
# 28/28 [==============================] - 2s 56ms/step - loss: 1.1646e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 100/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 13ms/step
# array([[0.39826924, 0.39648288],
#        [0.3976732 , 0.39603254],
#        [0.39303613, 0.39171314],
#        [0.39716783, 0.39549282],
#        [0.4011959 , 0.39928493]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1409.3593, 1403.0776],
#        [1408.2543, 1402.2429],
#        [1399.6576, 1394.2377],
#        [1407.3174, 1401.2427],
#        [1414.785 , 1408.2708]], dtype=float32)

# %% [markdown]
# **VISUALIZING ACTUAL VS PREDICTED DATA**

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1409.359253      1403.077637
# 2020-05-28  1396.86  1416.73     1408.254272      1402.242920
# 2020-05-29  1416.94  1428.92     1399.657593      1394.237671
# 2020-06-01  1418.39  1431.82     1407.317383      1401.242676
# 2020-06-02  1430.55  1439.22     1414.785034      1408.270752

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# **PREDICTING UPCOMING 10 DAY**S

# %%
# Creating a dataframe and adding 10 days to existing index

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2362.888916      2326.540527
# 2021-06-10  2494.01  2521.60     2366.929199      2332.729492
# 2021-06-11  2524.92  2513.93     2377.006104      2343.867188
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
